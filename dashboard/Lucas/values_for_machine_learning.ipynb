# %%
# Import our dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter

# %%
# Import dataset - application_record.csv
application_record_df = pd.read_csv('../../resources/datasets/application_record.csv')

# %%
# Find number of duplicates in 'ID' column
len(application_record_df['ID']) - len(application_record_df['ID'].unique())
# Out:
# 47

# %%
# Drop the duplicate entries from the 'ID' Column

application_record_df = application_record_df.drop_duplicates('ID', keep='last')

# %%
# Replace nulls with "No Occupation Type"
application_record_df["OCCUPATION_TYPE"].fillna("No Occupation Type", inplace = True)
application_record_df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0                1                1           0           0
# 1                1                1           0           0
# 2                1                0           0           0
# 3                1                0           1           1
# 4                1                0           1           1
# ...            ...              ...         ...         ...
# 438552           1                0           0           0
# 438553           1                0           0           0
# 438554           1                1           0           0
# 438555           1                0           0           0
# 438556           1                0           1           0
#
#            OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0       No Occupation Type              2.0
# 1       No Occupation Type              2.0
# 2           Security staff              2.0
# 3              Sales staff              1.0
# 4              Sales staff              1.0
# ...                    ...              ...
# 438552  No Occupation Type              1.0
# 438553            Laborers              1.0
# 438554         Sales staff              1.0
# 438555  No Occupation Type              2.0
# 438556         Sales staff              2.0
#
# [438510 rows x 18 columns]

# %% [markdown]
# application_record_df['AGE'] = round(application_record_df['DAYS_BIRTH'] / -365, 2)

# %%
application_record_df['EMPLOYMENT_PERIOD'] = round(application_record_df['DAYS_EMPLOYED'] / -365, 2)

# %%
application_record_df['AMT_INCOME_TOTAL'] = application_record_df['AMT_INCOME_TOTAL'] / 100000

# %% [markdown]
# ## Find the unique occupations that users can pick from

# %%
application_record_df['EMPLOYMENT_PERIOD'] = round(application_record_df['DAYS_EMPLOYED'] / -365, 2)

# %%
application_record_df['AGE'] = round(application_record_df['DAYS_BIRTH'] / -365, 2)

# %%
Columns_to_remove_application = ['DAYS_BIRTH', 'DAYS_EMPLOYED','FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL']


application_record_df.drop(labels=Columns_to_remove_application,axis=1,inplace=True)

application_record_df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                  4.275               Working               Higher education
# 1                  4.275               Working               Higher education
# 2                  1.125               Working  Secondary / secondary special
# 3                  2.700  Commercial associate  Secondary / secondary special
# 4                  2.700  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552             1.350             Pensioner  Secondary / secondary special
# 438553             1.035               Working  Secondary / secondary special
# 438554             0.540  Commercial associate               Higher education
# 438555             0.720             Pensioner  Secondary / secondary special
# 438556             1.215               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE     OCCUPATION_TYPE  \
# 0             Civil marriage   Rented apartment  No Occupation Type
# 1             Civil marriage   Rented apartment  No Occupation Type
# 2                    Married  House / apartment      Security staff
# 3       Single / not married  House / apartment         Sales staff
# 4       Single / not married  House / apartment         Sales staff
# ...                      ...                ...                 ...
# 438552             Separated  House / apartment  No Occupation Type
# 438553  Single / not married  House / apartment            Laborers
# 438554  Single / not married       With parents         Sales staff
# 438555               Married  House / apartment  No Occupation Type
# 438556               Married  House / apartment         Sales staff
#
#         CNT_FAM_MEMBERS  EMPLOYMENT_PERIOD    AGE
# 0                   2.0              12.44  32.89
# 1                   2.0              12.44  32.89
# 2                   2.0               3.11  58.83
# 3                   1.0               8.36  52.36
# 4                   1.0               8.36  52.36
# ...                 ...                ...    ...
# 438552              1.0           -1000.67  62.24
# 438553              1.0               8.24  43.67
# 438554              1.0               1.02  22.38
# 438555              2.0           -1000.67  59.38
# 438556              2.0               3.29  51.67
#
# [438510 rows x 14 columns]

# %%
unique_occupations = application_record_df["OCCUPATION_TYPE"].unique()
sorted(unique_occupations)
# Out:
# ['Accountants',
#  'Cleaning staff',
#  'Cooking staff',
#  'Core staff',
#  'Drivers',
#  'HR staff',
#  'High skill tech staff',
#  'IT staff',
#  'Laborers',
#  'Low-skill Laborers',
#  'Managers',
#  'Medicine staff',
#  'No Occupation Type',
#  'Private service staff',
#  'Realty agents',
#  'Sales staff',
#  'Secretaries',
#  'Security staff',
#  'Waiters/barmen staff']

# %% [markdown]
# ## Find the unique housing types that users can pick from

# %%
unique_housing_types = application_record_df["NAME_HOUSING_TYPE"].unique()
sorted(unique_housing_types)
# Out:
# ['Co-op apartment',
#  'House / apartment',
#  'Municipal apartment',
#  'Office apartment',
#  'Rented apartment',
#  'With parents']

# %% [markdown]
# ## Find the unique family status that users can pick from

# %%
unique_family_status = application_record_df["NAME_FAMILY_STATUS"].unique()
sorted(unique_family_status)
# Out:
# ['Civil marriage', 'Married', 'Separated', 'Single / not married', 'Widow']

# %% [markdown]
# ## Find the unique education type that users can pick from

# %%
unique_education_type = application_record_df["NAME_EDUCATION_TYPE"].unique()
sorted(unique_education_type)
# Out:
# ['Academic degree',
#  'Higher education',
#  'Incomplete higher',
#  'Lower secondary',
#  'Secondary / secondary special']

# %% [markdown]
# ## Find the unique income type that users can pick from

# %%
unique_income_type = application_record_df["NAME_INCOME_TYPE"].unique()
sorted(unique_income_type)
# Out:
# ['Commercial associate', 'Pensioner', 'State servant', 'Student', 'Working']
